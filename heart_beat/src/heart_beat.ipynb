# %%
import torch
import torchaudio

import matplotlib.pyplot as plt

# %%
a = torchaudio.load('../data/set_a/artifact__201012172012.wav')

# %%
type(a[0])
print(type(a[1]))
# Out:
# <class 'int'>

# %%
plt.plot(a[0].view(-1)[:10000])
